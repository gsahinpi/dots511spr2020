# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm
import scipy.stats as stats
import pandas as pd

# %%
df = pd.read_csv("Data/istanbul_deaths_2008_2020.csv")

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm
import scipy.stats as stats
import pandas as pd

# %%
dfraw = pd.read_csv("Data/istanbul_deaths_2008_2020.csv")

# %%
dfraw.plot()

# %%
dfraw["Date"]=pd.to_datetime(dfraw['Date'].astype(str), format='%d/%m/%Y')

# %%
dfraw = dfraw.set_index('Date')

# %%
dfraw.plot()

# %%
df7avaragae=dfraw.resample('7D').mean()
df7sum=dfraw.resample('7D').sum()
dfyearlyaverage=dfraw.resample('Y').mean()

# %%
df7avaragae.plot(label="average mortality")
df7sum.plot()
dfyearlyaverage.plot()

# %%
dfyearlyaverage
# Out:
#                 Number
# Date
# 2008-12-31  137.349727
# 2009-12-31  147.506849
# 2010-12-31  151.038147
# 2011-12-31  157.134247
# 2012-12-31  165.065574
# 2013-12-31  168.734247
# 2014-12-31  183.898630
# 2015-12-31  193.282192
# 2016-12-31  199.330601
# 2017-12-31  204.342466
# 2018-12-31  204.082192
# 2019-12-31  208.501370
# 2020-12-31  248.872727

# %%
df=df7avaragae

# %%
df
# Out:
#                 Number
# Date
# 2008-01-01  142.857143
# 2008-01-08  145.714286
# 2008-01-15  152.142857
# 2008-01-22  156.000000
# 2008-01-29  150.714286
# ...                ...
# 2020-03-17  249.428571
# 2020-03-24  261.571429
# 2020-03-31  316.285714
# 2020-04-07  313.571429
# 2020-04-14  293.000000
#
# [642 rows x 1 columns]

# %%
col         = 'DATE'
conditions  = [ df.index.year == 2008,
               df.index.year == 2009,df.index.year == 2010,df.index.year == 2011,
df.index.year == 2012,df.index.year == 2013,df.index.year == 2014,df.index.year == 2015,df.index.year == 2016,
              df.index.year == 2017,df.index.year == 2018,df.index.year == 2019,df.index.year == 2020]
choices     = [12697164,#2008
               12915158,#2009
               13255685,#2010
               13624240,#11
               14160467,#12
               14377018,#13
               14657434,#14
               14657434,#15
               14804116,#16
               15029231,#2017
               15067724,#2018
               15519267,#2019
               15713258#20
              ]

# %%
df7avaragae["population"] = np.select(conditions, choices, default=np.nan)

# %%
df7avaragae
# Out:
#                 Number  population
# Date
# 2008-01-01  142.857143  12697164.0
# 2008-01-08  145.714286  12697164.0
# 2008-01-15  152.142857  12697164.0
# 2008-01-22  156.000000  12697164.0
# 2008-01-29  150.714286  12697164.0
# ...                ...         ...
# 2020-03-17  249.428571  15713258.0
# 2020-03-24  261.571429  15713258.0
# 2020-03-31  316.285714  15713258.0
# 2020-04-07  313.571429  15713258.0
# 2020-04-14  293.000000  15713258.0
#
# [642 rows x 2 columns]

# %%
df7avaragae["density"]=df7avaragae["Number"]/df7avaragae["population"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/stat-rethink2-pymc3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'population'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-ba2f5f113442> in <module>
# ...

# %%
df7avaragae
# Out:
#                 Number  population   density
# Date
# 2008-01-01  142.857143  12697164.0  0.000011
# 2008-01-08  145.714286  12697164.0  0.000011
# 2008-01-15  152.142857  12697164.0  0.000012
# 2008-01-22  156.000000  12697164.0  0.000012
# 2008-01-29  150.714286  12697164.0  0.000012
# ...                ...         ...       ...
# 2020-03-17  249.428571  15713258.0  0.000016
# 2020-03-24  261.571429  15713258.0  0.000017
# 2020-03-31  316.285714  15713258.0  0.000020
# 2020-04-07  313.571429  15713258.0  0.000020
# 2020-04-14  293.000000  15713258.0  0.000019
#
# [642 rows x 3 columns]

# %%
df.plot(x='population', y='Number', style="o")

# %%
df7avaragae["density"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/stat-rethink2-pymc3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'density'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-27c4dc171a4b> in <module>
# ...

# %%
col         = 'DATE'
conditions  = [ dfyearlyaverage.index.year == 2008,
               dfyearlyaverage.index.year == 2009,dfyearlyaverage.index.year == 2010,dfyearlyaverage.index.year == 2011,
dfyearlyaverage.index.year == 2012,dfyearlyaverage.index.year == 2013,dfyearlyaverage.index.year == 2014,dfyearlyaverage.index.year == 2015,dfyearlyaverage.index.year == 2016,
              dfyearlyaverage.index.year == 2017,dfyearlyaverage.index.year == 2018,dfyearlyaverage.index.year == 2019,dfyearlyaverage.index.year == 2020]
choices     = [11691000#8
               12129000#9
               12585000#10
               113058000#11
               13419000#12
               14377018,#13
               13902000#14
               14127000#15
               14804116,#16
               14332000#16
               14540000#17
               15519267,#2019
               15713258#20
              ]
15190000#20
14968000#19
14751000#18

# %%
dfyearlyaverage["population"] = np.select(conditions, choices, default=np.nan)

# %%
dfyearlyaverage["density"]=(dfyearlyaverage["Number"]/dfyearlyaverage["population"])*1E5
dfyearlyaverage
# Out:
#                 Number  population   density
# Date
# 2008-12-31  137.349727  12697164.0  1.081735
# 2009-12-31  147.506849  12915158.0  1.142122
# 2010-12-31  151.038147  13255685.0  1.139422
# 2011-12-31  157.134247  13624240.0  1.153343
# 2012-12-31  165.065574  14160467.0  1.165679
# 2013-12-31  168.734247  14377018.0  1.173639
# 2014-12-31  183.898630  14657434.0  1.254644
# 2015-12-31  193.282192  14657434.0  1.318663
# 2016-12-31  199.330601  14804116.0  1.346454
# 2017-12-31  204.342466  15029231.0  1.359634
# 2018-12-31  204.082192  15067724.0  1.354433
# 2019-12-31  208.501370  15519267.0  1.343500
# 2020-12-31  248.872727  15713258.0  1.583839

# %%
dfyearlyaverage["density"].plot()

# %%
dfyearlyaverage.plot(x='population', y='density', style="o")

# %%
df7avaragae
# Out:
#                 Number  population   density
# Date
# 2008-01-01  142.857143  12697164.0  0.000011
# 2008-01-08  145.714286  12697164.0  0.000011
# 2008-01-15  152.142857  12697164.0  0.000012
# 2008-01-22  156.000000  12697164.0  0.000012
# 2008-01-29  150.714286  12697164.0  0.000012
# ...                ...         ...       ...
# 2020-03-17  249.428571  15713258.0  0.000016
# 2020-03-24  261.571429  15713258.0  0.000017
# 2020-03-31  316.285714  15713258.0  0.000020
# 2020-04-07  313.571429  15713258.0  0.000020
# 2020-04-14  293.000000  15713258.0  0.000019
#
# [642 rows x 3 columns]

# %%
df["population"].plot()
